# %%
pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: transformers in /usr/local/lib/python3.9/dist-packages (4.28.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from transformers) (2.27.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /usr/local/lib/python3.9/dist-packages (from transformers) (0.13.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from transformers) (23.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.9/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers) (6.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.9/dist-packages (from transformers) (0.13.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers) (3.11.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (3.4)

# %%
from transformers import pipeline

pipe = pipeline(model="facebook/bart-large-mnli")

# %%
text_file = open("User Stories.txt", "r")
stories = text_file.readlines()

# %%
stories
# Out:
# ["As a biologist, I want the application to provide accurate classification results with a minimum accuracy of 90% for binary classification problems, as evaluated by metrics such as F1-score, Recall, Precision, Accuracy or Mean squared error, so that I can trust the model's results and make informed decisions based on the predictions.\n",
#  'As a biologist, I want to use supervised classification algorithms such as random forest, logistic regression, or deep learning neural networks to classify cancer subtypes based on gene expression profiles, so that I can accurately identify different cancer subtypes and potentially develop targeted therapies.\n',
#  'As a social media manager, I want the system to monitor the social network and detect changes in information diffusion so that I can adjust my social media strategies as needed.\n',
#  'As a data analyst, I want the system to provide a detailed analysis of information diffusion within the social network so that I can understand how users are interacting with the system.\n',
#  'As a law student, I want the system to generate accurate and concise summaries of legal documents so that I can quickly understand their content.\n',
#  'As a legal professional, I want the system to perform sentiment analysis on legal documents and opinions related to specific issues so that I can identify the emotions and opinions expressed in the text.\n',
#  'As a producer, I want the system to be able to access large sets of actor and actress data to identify their physical characteristics and assign roles in a scalable and efficient manner, so that I can reduce the time and effort required to find suitable candidates.\n',
#  'As a producer, I want the system to be able to access large sets of cinematic production data to identify the most successful films, the most popular genres, and production trends in order to identify the most suitable casting directors, so that I can make more informed decisions when selecting casting directors.\n',
#  'As a news professional, I want the machine learning system to be adaptable and flexible enough to handle changes in the news domain, enabling it to provide relevant and informative summaries of news articles regardless of their topic.\n',
#  'As a news reader, I want the machine learning system to use various summarization techniques, such as TextRank and LSA-based summarization, to generate concise yet informative summaries of the clustered news articles, enabling me to quickly and efficiently digest news content.\n',
#  'As a sports fan or journalist, I want the system to classify teams or players based on their past performances, using algorithms such as Elo rating or Bayesian ranking, so that I can make informed predictions about future results and create engaging content.\n',
#  'As a data analyst or researcher in the sports domain, I want the system to be able to use cloud-based processing platforms and big data analytics, so that the model can handle large amounts of sports data and obtain scalable and efficient regressions and classifications, for making timely and accurate predictions.\n',
#  'As a sports analyst, I want to implement sophisticated ranking algorithms to evaluate the performance of teams or players based on their past records and predict future outcomes with greater accuracy.\n',
#  'As a biologist, I want to use unsupervised clustering algorithms such as K-means, hierarchical clustering, or principal component analysis to identify molecular subtypes of cancer based on genomic data, so that I can gain insights into the underlying biological mechanisms driving cancer subtypes.\n',
#  'As a cardiologist, I want the system to identify patterns in Echo signals that may indicate the presence of cardiac disease so that I can diagnose and treat patients accurately.\n',
#  'As a sentiment analysis expert in Psychology, I want the system to determine the sentiment of a sentence by using the Lexicon-Method Based Sentiment Analysis Algorithms algorithm so that I can analyze the emotional content of text data for psychological research on emotions and cognition.\n',
#  'As a network administrator, I want the system to distinguish between regular and anomalous data transmissions using classification algorithms, so that potential failures can be predicted and resolved before they occur, and network security can be maintained.\n',
#  'As a plant scientist, I want the system to identify the most informative genomic features with high precision and recall, so that I can trust the results of the analysis and make informed decisions.\n',
#  'As a Political Science official, I want the system to display the final district boundaries obtained from the data, so that I can use the model as a tool to reduce inequities such as gerrymandering and electoral manipulations and improve representativeness.\n',
#  'As a biologist, I want to access large-scale genomic datasets such as The Cancer Genome Atlas (TCGA) or International Cancer Genome Consortium (ICGC) to get the data necessary to perform this task, so that I can analyze a diverse range of cancer types and gain a comprehensive understanding of cancer biology.\n',
#  'As a marketing manager, I want the system to identify the most influential nodes in the social network using graph diffusion techniques so that I can create targeted advertising campaigns.\n',
#  'As a legal researcher, I want the system to identify similarities and differences between different legal documents so that I can compare and contrast different cases and judgments.\n',
#  'As a cognitive psychologist, I want the system to recognize potential post bias through Natural Language Processing algorithms so that I can understand the cognitive processes underlying the interpretation of biased information by individuals in my research on cognitive biases.\n',
#  "As a biologist, I want the application to use interpretability techniques such as feature importance scores, decision trees, or saliency maps to understand the underlying biological mechanisms and validate the model's predictions, so that I can gain insights into the biological mechanisms underlying cancer subtypes and identify the genes and pathways driving the classification results.\n",
#  "As a cardiologist, I want the system to process Echo signals so that I can analyze the structure and function of a patient's heart and detect any abnormalities.\n",
#  'As a network administrator, I want the system to categorize data packets based on priority using classification algorithms and route them appropriately to avoid network congestion, so that high-priority data can be processed first and network performance can be maintained.\n',
#  'As a network administrator, I want the system to monitor the network topology and identify unusual activity using clustering algorithms, so that I can take necessary actions to prevent network security breaches.\n',
#  'As a surveillance system operator, I want the system to automatically adapt to lighting conditions and image/video quality, so that I can use the system in different environments and lighting conditions to monitor activities and ensure safety.\n',
#  'As an advertising data analyst, I want the system to preprocess and clean collected advertising data, including outlier detection, data imputation, data normalization, and removing any inconsistencies or missing values, so that the accuracy of the ad ranking and placement optimization can be improved.\n',
#  'As an advertising data analyst, I want the system to continuously learn from new data and adapt to changing trends and user behaviors, so that the ad ranking and placement optimization strategies can be updated to reflect current trends.\n',
#  'As an advertising data analyst, I want the system to use appropriate ranking techniques (e.g. PageRank or LambdaMART), so that advertisements can be accurately ranked based on their potential impact.\n',
#  'As an advertising data analyst, I want the system to evaluate the performance of various machine learning algorithms and techniques for ranking and placement tasks, so that the best algorithm can be chosen for the provided dataset.\n',
#  'As a quant researcher, I want the ability to select the specific machine learning algorithm for predicting the price of financial products, so that I can choose the best algorithm for my investment needs.\n',
#  'As a quant developer, I want an interactive dashboard that allows users to customize the input parameters of the machine learning model, such as the time interval considered for price prediction, so that users can customize the system to their investment needs.\n',
#  'As a data scientist in the finance industry, I want the system to identify and handle any outliers or extreme values in the data that may affect the accuracy of price predictions, so that I can ensure the accuracy of the predictions.\n',
#  'As a machine learning specialist, I want the system to integrate machine learning techniques to improve the quality of the graph diffusion analysis so that I can make more accurate predictions about user behavior.\n',
#  'As a legal professional, I want the system to handle unstructured legal text data, such as cases, laws, contracts, and legislative documents, so that I can get accurate sentiment analysis and representation learning results.\n',
#  'As a legal researcher, I want the system to create efficient and effective document embeddings for downstream tasks using representation learning techniques.\n',
#  'As a legal researcher, I want the system to perform speaker attribution and sentiment analysis for each speaker on case documents so that I can understand the emotions of all participants.\n',
#  'As a legal professional, I want the system to detect plagiarism in legal texts, identifying similarities and coincidences with other existing legal documents, so that I can ensure the originality of legal documents.\n',
#  'As a legal translator, I want the system to automatically translate legal texts from one language to another while maintaining the accuracy and coherence of the legal language.\n',
#  'As a casting director, I want the system to recommend me for specific casting selection activities based on my abilities, experience, and preferences, so that I can increase my chances of being selected for projects that match my expertise.\n',
#  'As a casting director, I want the system to use a content-based filtering technique to analyze the characteristics of actors and actresses and assign them specific roles, so that I can ensure that the right candidates are selected for the right roles.\n',
#  "As a casting director, I want the system to use algorithms for the classification of an actor's skills to understand similarities between candidates and affinity with a particular role, so that I can make better casting decisions and increase the chances of producing successful films.\n",
#  'As a producer, I want the system to use a collaborative filtering algorithm to suggest suitable actors for specific roles based on their abilities, experience, and suitability, so that I can make more informed casting decisions and increase the chances of producing successful films.\n',
#  'As a producer, I want the system to use a content-based filtering technique to analyze the characteristics of casting directors and assign them specific casting selection activities, so that I can ensure that the right casting director is assigned to the right project.\n',
#  "As a producer, I want the system to use algorithms for the classification of a casting director's skills to understand similarities between candidates and required coverage affinity, so that I can ensure that the right casting director is selected for the right project.\n",
#  'As a producer, I want the system to use the technique of semantic analysis (Latent Semantic Analysis) on the resumes of all casting directors to extract and analyze significant data, compare them with the required characteristics, and assign a casting director to a specific activity, so that I can ensure that the right casting director is assigned to the right project.\n',
#  'As a news publisher, I want the machine learning system to use a range of clustering techniques, such as K-means and Hierarchical clustering, to group similar news articles together based on their content, allowing me to efficiently categorize and organize news content for publishing.\n',
#  'As a news correspondent, I want the machine learning system to be able to handle news articles in multiple languages, so that I can analyze news from various regions of the world and gain a broader perspective on global events.\n',
#  'As a plant scientist, I want the system to use matching techniques such as Support Vector Regression or K-Nearest Neighbors to predict the phenotype of a plant based on its genomic features, so that I can use this information for breeding or crop improvement.\n',
#  'As a plant scientist, I want the system to match the genomic features with the corresponding phenotypic data, such as plant height, biomass, or disease susceptibility, so that I can understand the genetic basis of different plant traits.\n',
#  'As a Political Science official, I want the system to validate the trained model and obtain metrics related to the quality of the electoral districting process, such as political representation and the fairness and equity of decisions made.\n',
#  'As a Political Science official, I want the system to perform spatio-temporal process learning, using techniques such as recurrent neural networks, to analyze historical voting patterns, population growth, and other relevant data to create district boundaries that take into consideration the prediction of future election behavior. This will help to reduce inequity and gerrymandering and improve accuracy and representativeness.\n',
#  "As a data analyst or researcher in the sports domain, I want the system to be able to normalize input data, in order to reduce variance and ensure that input values are comparable, so that the model's predictions are more accurate.\n",
#  'As a coach, I want to use advanced supervised regression algorithms to accurately predict the performance of my athletes in complex and dynamic team sports scenarios, such as soccer or basketball.\n',
#  'As a transportation analyst, I want the ML model to perform edge addition operations, so that I can improve the accuracy of risk evaluation by adding relevant data.\n',
#  'As a transportation analyst, I want the ML model to produce results using independent features for prediction, such as road networks, traffic flows, and spatial and temporal data, so that I can use different types of data to evaluate risk accurately.\n',
#  'As a legal analyst, I want the system to perform sentiment analysis on legal texts so that I can understand the tone and attitude of legal documents.\n',
#  'As a casting director, I want the system to use the technique of semantic analysis (Latent Semantic Analysis) on the scripts of all roles to extract significant data, compare them with the characteristics of actors, and recommend actors and actresses with a higher compatibility rate, so that I can reduce the time and effort required to find suitable candidates.\n',
#  "As a sports organization, I want to be able to upload our own customized sports data, such as players' past performances or data on environmental conditions, in order to improve the accuracy of the Machine Learning model's predictions and make data-driven decisions.\n",
#  'As a transportation analyst, I want the ML model to perform node deletion operations, so that I can improve the accuracy of risk evaluation by removing irrelevant data.\n',
#  'As a legal professional, I want the system to provide insights into the attitudes and emotions surrounding specific legal issues so that I can make more informed decisions and prepare for cases better.\n',
#  'As a legal professional, I want the system to "neutralize" the sentiment of a legal document while preserving its meaning so that I can create neutral documents for downstream tasks.\n',
#  'As a network administrator, I want the system to update the network topology with additional nodes and edges using graph incrementing algorithms, so that I can capture relationships between devices and applications and maintain an up-to-date network topology.\n',
#  'As an advertising data analyst, I want the system to extract meaningful features from collected data, such as ad engagement data, user demographics, and ad placement data, to improve the accuracy of ad ranking and placement optimization.\n',
#  'As a machine learning practitioner, I want the system to evaluate and compare the performance of different clustering and summarization algorithms, so that I can select the best algorithm for my specific news data and analytical needs.\n',
#  "As a biologist, I want the application to provide continuous monitoring and evaluation of the machine learning model's performance and accuracy, with feedback loops to improve the model over time, so that I can adapt the model to changing biological conditions and improve its performance over time.\n",
#  "As a network administrator, I want the system to automatically attach more resources to an application if it's recognized that more resources are needed to fulfill its tasks, so that applications can run efficiently.\n",
#  'As a network administrator, I want to be able to allocate and deallocate resources for the running of available applications on the network, so that I can ensure that resources are used efficiently.\n',
#  'As a legal expert, I want the system to create document embeddings that can capture the similarities and differences between legal documents on specific legal topics so that I can better understand similar cases.\n',
#  'As a user of the machine learning system, I need it to leverage cloud-based computing platforms and big data analytics to handle the high volume and dimensionality of news data, enabling me to perform efficient and scalable clustering and summarization.\n',
#  'As a plant scientist, I want the system to match the genomic features with the phenotypic data in no more than an hour, so that I can quickly analyze and interpret the results and plan my next experiment accordingly.\n',
#  'As a biologist, I want to use data preparation techniques such as sampling, feature selection, data cleaning, parallel processing, and dimensionality reduction to be able to process large-scale omics data, so that I can optimize the performance of the machine learning models and reduce the impact of noise and spurious correlations.\n',
#  'As a cardiologist, I want it to use ML algorithms for learning spatio-temporal processes so that it can continuously improve its accuracy in detecting and diagnosing cardiac diseases.\n',
#  'As a network administrator, I want the system to adapt dynamically to changing network needs using reinforcement learning algorithms, so that the network can respond to changing conditions and maintain optimal performance.\n',
#  "As a network administrator, I want the system to automatically detach resources from an application if it's recognized that too many resources are attached to it but aren't being used, so that resources can be used efficiently.\n",
#  'As a social media analyst, I want the system to acquire, process, and analyze data from a social network so that I can identify trends and patterns in user behavior.\n',
#  'As a product manager, I want the system to adapt to changes in the social network to ensure the continuous effectiveness of advertising strategies and user engagement.\n',
#  "As a finance investor, I want to access a company's financial information to extract useful metrics for price prediction of that share.\n",
#  'As a transportation analyst, I want the ML model to perform node addition operations, so that I can improve the accuracy of risk evaluation by adding relevant data.\n',
#  'As a network administrator, I want the system to use cloud-based computing platforms and big data analytics to manage large volumes of network traffic data and achieve scalable and efficient graph processing, so that network performance can be maintained even under heavy loads.\n',
#  'As a network administrator, I want to be able to view an updated graph that represents all connections between applications and devices, so that I can easily track the network topology.\n',
#  "As a finance investor, I want to see the sentiment/opinion of other investors on a financial investment product to make informed predictions about the product's value.\n",
#  'As a digital marketer, I want the system to personalize advertising messages for the most influential nodes in the social network so that I can increase the effectiveness of my campaigns.\n',
#  'As a law firm administrator, I want the system to classify different types of legal documents so that I can easily manage and retrieve them.\n',
#  'As a literary researcher, I want to be able to translate a book or article into another language in the system so that I can study it in my preferred language.\n',
#  'As a literary researcher, I want to be able to view a summary of the content of a book or article in the system so that I can quickly understand its topic.\n',
#  'As a social network analyst in the Psychology field, I want the system to analyze the connections between users by using a Graph Mining algorithm so that I can understand the social networks and relationships between individuals in my research on social psychology.\n',
#  'As a coach or team manager, I want the system to predict the number of points or goals a player is likely to score in a given game or season, based on a series of input features such as age, training regime, past injuries, and environmental conditions, so that I can develop game strategies and improve team performance.\n',
#  "As a sports enthusiast, I want to use an ML-based tool to predict the number of points or goals my favorite player will score in the upcoming game or season based on various factors, including their past performance, the team's history, and environmental conditions.\n",
#  "As a cardiologist, I want the system to recognize anomalies in ECG signals so that I can identify any irregularities in a patient's heart activity and determine the appropriate treatment.\n",
#  "As a cardiologist, I want the system to recognize anomalies in Echo signals so that I can identify any irregularities in a patient's heart structure or function and determine the appropriate treatment.\n",
#  'As a machine learning engineer, I want the system to optimize the hyperparameters of the machine learning algorithms used for clustering and summarization tasks, ensuring that the system achieves the best performance possible for my news data.\n',
#  'As a news analyst, I want the machine learning system to extract key entities and keywords from news articles to help me cluster and summarize similar articles based on their content.\n',
#  'As a social media researcher in the Psychology field, I want the system to collect social posts, comments, reactions, and awards from third-party social media such as Twitter and Reddit so that I can study the social and emotional dynamics of online interactions in my research on social media and mental health.\n',
#  'As a software developer, I want to leverage cloud-based computing platforms and big data analytics to achieve scalable and efficient regression and ranking for athlete performance predictions.\n',
#  'As a legal expert, I want the system to identify legal issues in texts, such as ambiguity or contradictions, so that I can ensure the accuracy and coherence of legal documents.\n',
#  'As a legal advisor, I want the system to provide automated legal recommendations based on the interpretation of legal texts and existing case law so that I can provide timely and accurate legal advice to clients.\n',
#  'As a network administrator, I want the system to dynamically allocate resources using reinforcement learning or genetic algorithms, based on network topology, traffic patterns, and performance requirements, so that the network can be optimized for efficiency and scalability.\n',
#  'As a quantitative analyst in the finance industry, I want the system to be able to handle large volumes of financial and market data, including historical stock prices, economic indicators, and company financial reports, to accurately predict the pricing of financial products, so that I can rely on the accuracy of the predictions.\n',
#  'As an advertising data analyst, I want the system to use feature selection techniques (e.g. principal component analysis or mutual information) to identify the most relevant features that affect ad performance, so that only the most important features are used for ad ranking and placement optimization.\n',
#  'As a plant scientist, I want the system to use feature selection techniques such as "Recursive Feature Elimination" or "Random Forest Importance" to identify the most informative genomic features so that I can focus on the most relevant genetic markers for my research.\n',
#  'As a transportation analyst, I want the ML model to be able to accept datasets modified by feature selection algorithms, so that I can use the most relevant features for risk evaluation.\n',
#  'As a transportation analyst, I want the ML model to be able to accept datasets not modified by feature selection algorithms, so that I can use all available features for risk evaluation.\n',
#  'As a biologist, I want to leverage cloud-based computing platforms and big data analytics to handle the high dimensionality of omics data and achieve scalable and efficient classification and clustering, so that I can analyze large-scale genomic datasets and gain insights into the mechanisms underlying cancer subtypes.\n',
#  'As a user of the system, I want it to utilize cloud platforms so that I can access the system and patient data from anywhere and on any device, without having to worry about hardware limitations or maintenance.\n',
#  "As a cardiologist, I want the system to process ECG signals so that I can analyze the electrical activity of a patient's heart and detect any abnormalities.\n",
#  'As a machine learning engineer, I want the system to automatically detect any errors or problems in the processing and report them, so that I can improve the accuracy and performance of the computer vision algorithms.\n',
#  'As a legal researcher, I want the system to extract relevant information from legal texts so that I can quickly find the information I need for my research.\n',
#  'As a news editor, I want the machine learning system to preprocess and clean news data to remove noise, irrelevant information, and duplicates, ensuring that the data is of high quality and free from redundancy.\n',
#  'As a network administrator, I want the system to recognize if an application is given too few resources to serve its purpose, so that I can allocate additional resources as needed.\n',
#  'As a legal analyst, I want the system to identify and extract legal arguments and reasoning expressed in legal documents so that I can better understand the legal reasoning involved in specific cases or issues.\n',
#  'As an economic analyst, I want the system to extract and collect data from large-scale advertising sources (e.g. online ads, billboards, TV commercials), so that I can analyze and understand the trends and patterns in the advertising industry.\n',
#  'As a finance investor, I want to receive alerts when a certain asset I hold is predicted to lose value in the near future to make an informed decision about whether to hold or sell it.\n',
#  'As a user of the system, I want it to manage large-scale data so that I can process and analyze large amounts of patient data efficiently.\n',
#  'As a network administrator, I want the system to manage traffic efficiently using real-time data flow, so that the number of nodes can be dynamically reduced or increased based on network traffic.\n',
#  'As a computer vision researcher, I want the system to be able to handle large amounts of data, with no limits on the number of files, so that I can process and analyze large datasets in computer vision research.\n',
#  'As a legal risk manager, I want the system to analyze legal risks associated with a contract or agreement, identifying possible legal gaps and potential risks, so that I can mitigate legal risks for the organization.']

# %%
with open('output.txt', 'w') as f:
  f.write('readme')

  for story in stories:
    results = pipe(story,candidate_labels=["advertising", "anomaly detection", "bias detection in language models", "bias detection in word embeddings", "classification", "clustering", "data summarization", "districting", "entity resolution", "graph augmentation", "graph diffusion", "graph mining", "machine translation", "matching", "pricing", "ranking", "regression", "representation learning", "resource allocation", "risk assessment", "sentiment analysis", "spatio-temporal process learning", "speech recognition", "subset selection", "task assignment"],)
    f.write('{},{},{}\n'.format(results['sequence'], results['labels'][0:4], results['scores'][0:4]))
  f.close()
