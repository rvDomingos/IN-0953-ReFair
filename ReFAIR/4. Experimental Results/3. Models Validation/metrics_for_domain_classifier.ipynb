# %%
import pandas as pd

# %%
#Original Requirements

#Oracles
y_true = ["Biology", "Biology", "Biology", "Biology", "Biology", "Biology", "Biology", "Biology", "Cardiology", "Cardiology", "Cardiology", "Cardiology", "Cardiology", "Cardiology", "Cardiology", "Cardiology", "Computer Networks", "Computer Networks", "Computer Networks", "Computer Networks", "Computer Networks", "Computer Networks", "Computer Networks", "Computer Networks", "Computer Networks", "Computer Networks", "Computer Networks", "Computer Networks", "Computer Networks", "Computer Vision", "Computer Vision", "Computer Vision", "Economics", "Economics", "Economics", "Economics", "Economics", "Economics", "Economics", "Finance & Marketing", "Finance & Marketing", "Finance & Marketing", "Finance & Marketing", "Finance & Marketing", "Finance & Marketing", "Finance & Marketing", "Information Systems", "Information Systems", "Information Systems", "Information Systems", "Information Systems", "Information Systems", "Information Systems", "Law", "Law", "Law", "Law", "Law", "Law", "Law", "Law", "Law", "Law", "Law", "Law", "Law", "Law", "Law", "Law", "Law", "Law", "Literature", "Literature", "Movies", "Movies", "Movies", "Movies", "Movies", "Movies", "Movies", "Movies", "Movies", "Movies", "News", "News", "News", "News", "News", "News", "News", "News", "News", "Plant Science", "Plant Science", "Plant Science", "Plant Science", "Plant Science", "Political Science", "Political Science", "Political Science", "Psychology", "Psychology", "Psychology", "Psychology", "Sport", "Sport", "Sport", "Sport", "Sport", "Sport", "Sport", "Sport", "Sport", "Transportation", "Transportation", "Transportation", "Transportation", "Transportation", "Transportation"]

#Predicted values
y_pred = ["Biology", "Biology", "Biology", "Biology", "Biology", "Biology", "Cardiology", "Education", "Biology", "Biology", "Social Media", "Social Media", "Biology", "Biology", "Information Systems", "Biology", "Biology", "Education", "Biology", "Biology", "Biology", "Biology", "Biology", "Biology", "Biology", "Biology", "Information Systems", "Sport", "Information Systems", "Biology", "Biology", "Biology", "Biology", "Finance & Marketing", "Biology", "Biology", "Education", "Biology", "Biology", "Education", "Biology", "Education", "Education", "Education", "Education", "Biology", "Finance & Marketing", "Biology", "Biology", "Finance & Marketing", "Biology", "Biology", "Biology", "Law", "Law", "Law", "Medicine", "Education", "Biology", "Education", "Biology", "Biology", "Biology", "Education", "Biology", "Biology", "Biology", "Education", "Movies", "Biology", "Information Systems", "Sport", "Movies", "Education", "Education", "Biology", "Education", "Biology", "Biology", "Education", "Education", "Biology", "Education", "Transportation", "Transportation", "Transportation", "Transportation", "Transportation", "Transportation", "Transportation", "Transportation", "Transportation", "Finance & Marketing", "Biology", "Finance & Marketing", "Biology", "Biology", "Education", "Biology", "Biology", "Education", "Library", "Social Media", "Transportation", "Sport", "Sport", "Sport", "Sport", "Sport", "Biology", "Biology", "Biology", "Biology", "Biology", "Biology", "Biology", "Biology", "Economics", "Economics"]

# Print the confusion matrix
#print(metrics.confusion_matrix(y_true, y_pred))

# Print the precision and recall, among other metrics
print(metrics.classification_report(y_true, y_pred, digits=3, zero_division = 1))
# Out:
#                      precision    recall  f1-score   support
#
#             Biology      0.100     0.750     0.176         8
#          Cardiology      0.000     0.000     0.000         8
#   Computer Networks      1.000     0.000     0.000        13
#     Computer Vision      1.000     0.000     0.000         3
#           Economics      0.000     0.000     0.000         7
#           Education      0.000     1.000     0.000         0
# Finance & Marketing      0.000     0.000     0.000         7
# Information Systems      0.000     0.000     0.000         7
#                 Law      1.000     0.167     0.286        18
#             Library      0.000     1.000     0.000         0
#          Literature      1.000     0.000     0.000         2
#            Medicine      0.000     1.000     0.000         0
#              Movies      0.000     0.000     0.000        10
#                News      1.000     0.000     0.000         9
# ...

# %%
#User Stories conversion

#Oracles
y_true = ["Biology", "Biology", "Biology", "Biology", "Biology", "Biology", "Biology", "Biology", "Cardiology", "Cardiology", "Cardiology", "Cardiology", "Cardiology", "Cardiology", "Cardiology", "Cardiology", "Computer Networks", "Computer Networks", "Computer Networks", "Computer Networks", "Computer Networks", "Computer Networks", "Computer Networks", "Computer Networks", "Computer Networks", "Computer Networks", "Computer Networks", "Computer Networks", "Computer Networks", "Computer Vision", "Computer Vision", "Computer Vision", "Economics", "Economics", "Economics", "Economics", "Economics", "Economics", "Economics", "Finance & Marketing", "Finance & Marketing", "Finance & Marketing", "Finance & Marketing", "Finance & Marketing", "Finance & Marketing", "Finance & Marketing", "Information Systems", "Information Systems", "Information Systems", "Information Systems", "Information Systems", "Information Systems", "Information Systems", "Law", "Law", "Law", "Law", "Law", "Law", "Law", "Law", "Law", "Law", "Law", "Law", "Law", "Law", "Law", "Law", "Law", "Law", "Literature", "Literature", "Movies", "Movies", "Movies", "Movies", "Movies", "Movies", "Movies", "Movies", "Movies", "Movies", "News", "News", "News", "News", "News", "News", "News", "News", "News", "Plant Science", "Plant Science", "Plant Science", "Plant Science", "Plant Science", "Political Science", "Political Science", "Political Science", "Psychology", "Psychology", "Psychology", "Psychology", "Sport", "Sport", "Sport", "Sport", "Sport", "Sport", "Sport", "Sport", "Sport", "Transportation", "Transportation", "Transportation", "Transportation", "Transportation", "Transportation"]

#Predicted values
y_pred = ["Biology", "Biology", "Biology", "Biology", "Biology", "Biology", "Biology", "Biology", "Cardiology", "Cardiology", "Cardiology", "Cardiology", "Cardiology", "Transportation", "Transportation", "Cardiology", "Computer Networking", "Computer Networking", "Computer Networking", "Computer Networking", "Computer Networking", "Computer Networking", "Computer Networking", "Computer Networking", "Computer Networking", "Computer Networking", "Computer Networking", "Computer Networking", "Computer Networking", "Computer Networking", "Health", "Computer Vision", "Education", "Education", "Urban Studies", "Urban Studies", "Urban Studies", "Movies", "Urban Studies", "Biology", "Biology", "Biology", "Biology", "Finance & Marketing", "Finance & Marketing", "Finance & Marketing", "Social Media", "Biology", "Social Media", "Information Systems", "Literature", "Finance & Marketing", "Computer Networking", "Law", "Law", "Law", "Law", "Law", "Law", "Law", "Law", "Law", "Law", "Law", "Law", "Law", "Law", "Law", "Law", "Law", "Law", "Literature", "Literature", "Medicine", "Biology", "Medicine", "Movies", "Movies", "Movies", "Movies", "Movies", "Movies", "Biology", "News", "Biology", "Transportation", "Biology", "News", "News", "News", "News", "News", "Plant Science", "Plant Science", "Plant Science", "Plant Science", "Plant Science", "Political Science", "Political Science", "Political Science", "Biology", "Biology", "Social Networks", "Social Media", "Sport", "Sport", "Literature", "Biology", "Sport", "Sport", "Sport", "News", "Sport", "Transportation", "Transportation", "Transportation", "Transportation", "Transportation", "Transportation"]

# Print the confusion matrix
#print(metrics.confusion_matrix(y_true, y_pred))

# Print the precision and recall, among other metrics
print(metrics.classification_report(y_true, y_pred, digits=3, zero_division = 1))
# Out:
#                      precision    recall  f1-score   support
#
#             Biology      0.400     1.000     0.571         8
#          Cardiology      1.000     0.750     0.857         8
# Computer Networking      0.000     1.000     0.000         0
#   Computer Networks      1.000     0.000     0.000        13
#     Computer Vision      1.000     0.333     0.500         3
#           Economics      1.000     0.000     0.000         7
#           Education      0.000     1.000     0.000         0
# Finance & Marketing      0.750     0.429     0.545         7
#              Health      0.000     1.000     0.000         0
# Information Systems      1.000     0.143     0.250         7
#                 Law      1.000     1.000     1.000        18
#          Literature      0.500     1.000     0.667         2
#            Medicine      0.000     1.000     0.000         0
#              Movies      0.857     0.600     0.706        10
# ...
